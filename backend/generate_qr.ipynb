# %% [markdown]
# ## Generate QR Code for User Token

# %%
import qrcode
user_token = "USR-RAJTILAK-998877"

# %%
# Configure the QR code
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
)

# %%
# Add the token data to the QR code
qr.add_data(user_token)
qr.make(fit=True)

# %%
# Generate the image and save it
img = qr.make_image(fill_color="black", back_color="white")
img.save("rajtilak_id.png")
print(f"Success! QR Code generated for token: {user_token}")
# Out:
# Success! QR Code generated for token: USR-RAJTILAK-998877
